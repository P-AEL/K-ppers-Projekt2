# %%
import pandas as pd

# %%
df = pd.read_parquet("DSCB310 - UE2 - Shopping Carts.parquet")

# %%
df
# Out:
#          order_id  product_id  add_to_cart_order  reordered  user_id  \
# index
# 5006171         1       13176                  6          0   112108
# 5006176         1       11109                  2          1   112108
# 5006175         1       10246                  3          0   112108
# 5006174         1       22035                  8          1   112108
# 5006173         1       49683                  4          0   112108
# ...           ...         ...                ...        ...      ...
# 2493330    606914       28849                  6          1   193225
# 3597250    606915       27966                  1          0   107102
# 3597251    606915       27845                  4          0   107102
# 3597252    606915       26940                  3          0   107102
# 3597253    606915       45007                  2          0   107102
#
#          order_number  order_dow  order_hour_of_day  days_since_prior_order  \
# index
# ...

# %%
#askndjasdn
# Out:
# range(1, 10)
