# %%
import pandas as pd

# %%
df = pd.read_parquet("DSCB310 - UE2 - Shopping Carts.parquet")

# %%
df.reset_index(inplace= True)

# %%
df
# Out:
#            index  order_id  product_id  add_to_cart_order  reordered  user_id  \
# 0        5006171         1       13176                  6          0   112108
# 1        5006176         1       11109                  2          1   112108
# 2        5006175         1       10246                  3          0   112108
# 3        5006174         1       22035                  8          1   112108
# 4        5006173         1       49683                  4          0   112108
# ...          ...       ...         ...                ...        ...      ...
# 6132664  2493330    606914       28849                  6          1   193225
# 6132665  3597250    606915       27966                  1          0   107102
# 6132666  3597251    606915       27845                  4          0   107102
# 6132667  3597252    606915       26940                  3          0   107102
# 6132668  3597253    606915       45007                  2          0   107102
#
# ...

# %%
df.describe().round(2)
# Out:
#             index    order_id  product_id  add_to_cart_order   reordered  \
# count  6132669.00  6132669.00  6132669.00         6132669.00  6132669.00
# mean   3066334.00   303414.08    25557.15               8.35        0.59
# std    1770349.19   175167.40    14094.40               7.13        0.49
# min          0.00        1.00        1.00               1.00        0.00
# 25%    1533167.00   151737.00    13512.00               3.00        0.00
# 50%    3066334.00   303245.00    25230.00               6.00        1.00
# 75%    4599501.00   455140.00    37866.00              11.00        1.00
# max    6132668.00   606915.00    49688.00             145.00        1.00
#
#           user_id  order_number   order_dow  order_hour_of_day  \
# count  6132669.00    6132669.00  6132669.00         6132669.00
# mean    103460.39         17.09        2.74              13.44
# std      59422.33         17.49        2.10               4.26
# ...

# %%
df_ai = pd.DataFrame(df.aisle.unique())

# %%
df_ai.sample(20)
# Out:
#                                  0
# 64                     pasta sauce
# 74               cleaning products
# 103     marinades meat preparation
# 44                         missing
# 46          nuts seeds dried fruit
# 101       hot cereal pancake mixes
# 39                  chips pretzels
# 70                      buns rolls
# 79                           other
# 75         salad dressing toppings
# 131                   kosher foods
# 3                  packaged cheese
# 65                  more household
# 11                   ice cream ice
# 41                        mint gum
# 120              cocoa drink mixes
# 53   refrigerated pudding desserts
# 87                    frozen meals
# 102                 prepared meals
# 68             baby bath body care

# %%
df_pn = pd.DataFrame(df.product_name.unique())

# %%
df_pn.to_clipboard()

# %% [markdown]
# **order_size und add_o_card_order**

# %%
df_g = df.groupby("order_id").agg(asd = ("add_to_cart_order", "max"), order_size= ("order_id", "count")).reset_index(drop= True)

# %%
df_g
# Out:
#         asd  order_size
# 0         8           8
# 1         3           3
# 2         5           5
# 3         3           3
# 4         2           2
# ...     ...         ...
# 606910    6           6
# 606911   13          13
# 606912   19          19
# 606913    8           8
# 606914    4           4
#
# [606915 rows x 2 columns]

# %%
df_g.loc[df_g.asd != df_g.order_size]
# Out:
# Empty DataFrame
# Columns: [asd, order_size]
# Index: []
